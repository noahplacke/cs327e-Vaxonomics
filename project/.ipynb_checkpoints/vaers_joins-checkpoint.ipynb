# %% [markdown]
# ### Queries with Joins on VAERS Dataset

# %%
# Remove limit on number of columns shown
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### Inner Join by ID (between Events and Vaccines tables) to identify details of vaccine administered to individuals who died as result of adverse event after vaccination, ordered by death date

# %%
# %%bigquery
# select DATEDIED, VAX_DATE, VAX_NAME, VAX_TYPE, VAX_MANU
# from vaers_staging.Events evn
# join vaers_staging.Vaccines vac on evn.VAERS_ID = vac.VAERS_ID
# where evn.DIED = true
# order by evn.DATEDIED desc
# limit 12
# Out:
#       DATEDIED    VAX_DATE                                     VAX_NAME  \
# 0   2019-12-08  2019-11-11               INFLUENZA (SEASONAL) (AFLURIA)
# 1   2019-11-27  2019-11-27                 DTAP + HEPB + IPV (PEDIARIX)
# 2   2019-11-18  2019-11-12                            ZOSTER (SHINGRIX)
# 3   2019-11-13  2019-01-11                  DTAP + IPV + HIB (PENTACEL)
# 4   2019-11-13  2019-01-11                          ROTAVIRUS (ROTATEQ)
# 5   2019-11-13  2019-01-11                        HEP B (RECOMBIVAX HB)
# 6   2019-11-13  2019-01-11                                HIB (HIBERIX)
# 7   2019-11-13  2019-01-11        VACCINE NOT SPECIFIED (NO BRAND NAME)
# 8   2019-11-08  2019-11-07  INFLUENZA (SEASONAL) (FLUARIX QUADRIVALENT)
# 9   2019-11-05  2019-11-04  INFLUENZA (SEASONAL) (FLUBLOK QUADRIVALENT)
# 10  2019-11-01  2019-10-01        VACCINE NOT SPECIFIED (NO BRAND NAME)
# 11  2019-10-29  2019-10-29     INFLUENZA (SEASONAL) (FLUZONE HIGH-DOSE)
#
#       VAX_TYPE                      VAX_MANU
# 0         FLU3                   CSL LIMITED
# 1   DTAPHEPBIP   GLAXOSMITHKLINE BIOLOGICALS
# 2       VARZOS   GLAXOSMITHKLINE BIOLOGICALS
# 3   DTAPIPVHIB                SANOFI PASTEUR
# 4          RV5              MERCK & CO. INC.
# 5          HEP              MERCK & CO. INC.
# 6         HIBV   GLAXOSMITHKLINE BIOLOGICALS
# 7          UNK          UNKNOWN MANUFACTURER
# 8         FLU4   GLAXOSMITHKLINE BIOLOGICALS
# 9        FLUR4  PROTEIN SCIENCES CORPORATION
# 10         UNK          UNKNOWN MANUFACTURER
# 11        FLU3                SANOFI PASTEUR

# %% [markdown]
# #### Inner Join by ID (between Events and Vaccines tables) to identify anatomic site of vaccine injection (VAX_ROUTE) of individuals who died as result of adverse event, ordered by vaccination date

# %% [markdown]
# ##### Legend for anatomic site of vaccine injection (VAX_ROUTE):
# IM - Intramuscular (Into muscle)\
# SC - Subcutaneous (Under skin) \
# SYR - Syringe (Not specified futher)

# %%
# %%bigquery
# select VAX_DATE, ONSET_DATE, VAX_ROUTE
# from vaers_staging.Events evn
# join vaers_staging.Vaccines vac on evn.VAERS_ID = vac.VAERS_ID
# where evn.DIED = true
# order by evn.VAX_DATE desc
# limit 12
# Out:
#       VAX_DATE  ONSET_DATE VAX_ROUTE
# 0   2019-11-27  2019-11-27        IM
# 1   2019-11-12  2019-11-13        SC
# 2   2019-11-11  2019-11-12        IM
# 3   2019-11-07  2019-11-08        IM
# 4   2019-11-04  2019-11-05        IM
# 5   2019-10-29  2019-10-29        IM
# 6   2019-10-23  2019-10-23       SYR
# 7   2019-10-23  2019-10-23       SYR
# 8   2019-10-09  2019-10-11        IM
# 9   2019-10-07  2019-10-08        IM
# 10  2019-10-01  2019-10-01        IM
# 11  2019-10-01  2019-10-01      None

# %% [markdown]
# #### Full Outer Join by ID (between Vaccines and Symptoms tables) to determine vaccines which resulted in adverse symptoms of blindness among patients, ordered by vaccine name

# %%
# %%bigquery
# select VAX_NAME, VAX_TYPE, VAX_MANU
# from vaers_staging.Vaccines vac
# full outer join vaers_staging.Symptoms sym on vac.VAERS_ID = sym.VAERS_ID
# where SYMPTOM1 = 'Blindness' or SYMPTOM2 = 'Blindness' or SYMPTOM3 = 'Blindeness'
# order by vac.VAX_NAME
# limit 12
# Out:
#                                         VAX_NAME VAX_TYPE  \
# 0                                 HEP A (HAVRIX)     HEPA
# 1                                 HEP A (HAVRIX)     HEPA
# 2                        HEP A + HEP B (TWINRIX)    HEPAB
# 3                               HPV (GARDASIL 9)     HPV9
# 4                               HPV (GARDASIL 9)     HPV9
# 5                               HPV (GARDASIL 9)     HPV9
# 6                   INFLUENZA (SEASONAL) (FLUAD)    FLUA3
# 7    INFLUENZA (SEASONAL) (FLUARIX QUADRIVALENT)     FLU4
# 8   INFLUENZA (SEASONAL) (FLULAVAL QUADRIVALENT)     FLU4
# 9       INFLUENZA (SEASONAL) (FLUZONE HIGH-DOSE)     FLU3
# 10   INFLUENZA (SEASONAL) (FLUZONE QUADRIVALENT)     FLU4
# 11   INFLUENZA (SEASONAL) (FLUZONE QUADRIVALENT)     FLU4
#
#                              VAX_MANU
# 0         GLAXOSMITHKLINE BIOLOGICALS
# 1         GLAXOSMITHKLINE BIOLOGICALS
# 2         GLAXOSMITHKLINE BIOLOGICALS
# 3                    MERCK & CO. INC.
# 4                    MERCK & CO. INC.
# 5                    MERCK & CO. INC.
# 6   NOVARTIS VACCINES AND DIAGNOSTICS
# 7         GLAXOSMITHKLINE BIOLOGICALS
# 8         GLAXOSMITHKLINE BIOLOGICALS
# 9                      SANOFI PASTEUR
# 10                     SANOFI PASTEUR
# 11                     SANOFI PASTEUR

# %% [markdown]
# #### Full Outer Join by ID (between Symptoms and Vaccines tables) to investigate adverse symptoms as result of HPV vaccine ordered by ID

# %%
# %%bigquery
# select SYMPTOM1, SYMPTOM2, SYMPTOM3
# from vaers_staging.Symptoms sym
# full outer join vaers_staging.Vaccines vac on vac.VAERS_ID = sym.VAERS_ID
# where VAX_TYPE = 'HPVX'
# order by vac.VAERS_ID desc
# limit 12
# Out:
#                                              SYMPTOM1  \
# 0                                            Erythema
# 1                          Precancerous cells present
# 2                                  Lip discolouration
# 3                                             Syncope
# 4                                Dermatitis acneiform
# 5   Loss of personal independence in daily activities
# 6                                              Chills
# 7                                             Pyrexia
# 8                                            Headache
# 9                             Extra dose administered
# 10                              Product storage error
# 11                            Extra dose administered
#
#                       SYMPTOM2       SYMPTOM3
# 0                    Skin warm           None
# 1        Smear cervix abnormal           None
# 2                         None           None
# 3                         None           None
# 4                         Rash   Rash papular
# 5                      Malaise    Oral herpes
# 6                      Fatigue  Hyperhidrosis
# 7                         None           None
# 8                      Pyrexia           None
# 9   Wrong product administered           None
# 10                        None           None
# 11                        None           None

# %% [markdown]
# #### Full Outer Join by ID (between Symptoms and Events tables) to investigate adverse symptoms of patients who had an ER visit and were diagnosed with life-threatening disease ordered by vaccination date

# %%
# %%bigquery
# select SYMPTOM1, SYMPTOM2, SYMPTOM3
# from vaers_staging.Symptoms sym
# full outer join vaers_staging.Events evn on sym.VAERS_ID = evn.VAERS_ID
# where evn.ER_VISIT = true and evn.L_THREAT = true
# order by evn.VAX_DATE desc
# Out:
#                                         SYMPTOM1  \
# 0                                      Dysphagia
# 1                         Urine output decreased
# 2                                   Barium enema
# 3                                Intussusception
# 4                                   Restlessness
# 5              CSF red blood cell count positive
# 6                   Obstructive airways disorder
# 7                               Muscle twitching
# 8                        Full blood count normal
# 9   Activated partial thromboplastin time normal
# 10                             Oedema peripheral
# 11                             Cardiac tamponade
#
#                             SYMPTOM2                     SYMPTOM3
# 0                  Electrocardiogram    Sensation of foreign body
# 1                           Vomiting                         None
# 2                        Dehydration       Diarrhoea haemorrhagic
# 3                Lid sulcus deepened           Procedural failure
# 4                                Tic  Tongue movement disturbance
# 5                           CSF test                     Dystonia
# 6                       Opisthotonus      Prothrombin time normal
# 7                  Muscular weakness    Musculoskeletal stiffness
# 8             Infantile back arching                     Insomnia
# 9    Apparent life threatening event                  Arthropathy
# 10              Pericardial drainage         Pericardial effusion
# 11  Catheterisation cardiac abnormal                     Dyspnoea

# %% [markdown]
# #### Inner Join by ID (between Events, Vaccines and Symptoms tables) to investigate type of vaccine and adverse symptoms of patients who recovered from adverse events in the state of Texas

# %%
# %%bigquery
# select VAX_NAME, VAX_TYPE, SYMPTOM1, SYMPTOM2, SYMPTOM3
# from (vaers_staging.Events evn join vaers_staging.Vaccines vac on evn.VAERS_ID = vac.VAERS_ID)
#     join vaers_staging.Symptoms sym on sym.VAERS_ID = evn.VAERS_ID
# where RECOVD = 'Y' and STATE = 'TX'
# limit 12
# Out:
#                                        VAX_NAME VAX_TYPE  \
# 0                                 TDAP (ADACEL)     TDAP
# 1                                 TDAP (ADACEL)     TDAP
# 2         VACCINE NOT SPECIFIED (NO BRAND NAME)      UNK
# 3                             ZOSTER (SHINGRIX)   VARZOS
# 4                             ZOSTER (SHINGRIX)   VARZOS
# 5      INFLUENZA (SEASONAL) (FLUZONE HIGH-DOSE)     FLU3
# 6                             ZOSTER (SHINGRIX)   VARZOS
# 7                             ZOSTER (SHINGRIX)   VARZOS
# 8                             ZOSTER (SHINGRIX)   VARZOS
# 9                            PNEUMO (PREVNAR13)    PNC13
# 10  INFLUENZA (SEASONAL) (FLUMIST QUADRIVALENT)    FLUN4
# 11                           PNEUMO (PREVNAR13)    PNC13
#
#                                             SYMPTOM1  \
# 0                                               Rash
# 1                                         Arthralgia
# 2                                        Hypersomnia
# 3                  Immediate post-injection reaction
# 4              Extensive swelling of vaccinated limb
# 5                                  Pain in extremity
# 6                                            Pyrexia
# 7                                          Urticaria
# 8                                        Oral herpes
# 9                                Peripheral swelling
# 10  Mycobacterium tuberculosis complex test positive
# 11                                         Urticaria
#
#                                 SYMPTOM2               SYMPTOM3
# 0                          Rash pruritic         Urine analysis
# 1                       Full blood count    Injection site pain
# 2                                   Rash               Swelling
# 3                      Pain in extremity                   None
# 4                Injection site erythema  Injection site warmth
# 5                                   None                   None
# 6                                   None                   None
# 7                                   None                   None
# 8   Prostatic specific antigen increased       Rash generalised
# 9                                   None                   None
# 10                                  Pain                   None
# 11                                  None                   None
