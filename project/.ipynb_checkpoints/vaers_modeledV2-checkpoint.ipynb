# %%
dataset_id = "vaers_modeled"
# !bq --location=US mk --dataset {dataset_id}
# Out:
# Dataset 'studied-brand-266702:vaers_modeled' successfully created.

# %% [markdown]
# ### Split staging Events table into separate entities: Patient table and Adverse_Event table

# %% [markdown]
# #### Create Patient table

# %%
# %%bigquery
#
# select DISTINCT ROW_NUMBER() OVER() as PATIENT_ID, VAERS_ID, STATE, AGE_YRS, SEX, ALLERGIES
# from vaers_staging.Events
# Out:
#        PATIENT_ID  VAERS_ID STATE  AGE_YRS SEX                  ALLERGIES
# 0              14    803845    WV     65.0   F            dexlansoprazole
# 1              45    820113    DE     67.0   U  Sulphate drugs Penicillin
# 2             123    794191    MS      NaN   M                       None
# 3             143    794340    AR      NaN   M                       None
# 4             239    794809    WV      NaN   M                       None
# ...           ...       ...   ...      ...  ..                        ...
# 44339       44141    819290    WI     89.0   F     clindamycin cephalexin
# 44340       44184    843628    WI     89.0   F                       none
# 44341       44209    815089    WI     90.0   F                       None
# 44342       44233    824511    WI     90.0   F                       none
# 44343       44324    841555    WI     95.0   F         Morphine, Tramadol
#
# [44344 rows x 6 columns]

# %% [markdown]
# #### Create Adverse_Event table

# %%
# %%bigquery
#
# select VAERS_ID, ONSET_DATE, RECOVD, DIED, DATEDIED, L_THREAT, OFC_VISIT, ER_VISIT, ER_ED_VISIT, HOSPITAL, HOSPDAYS, X_STAY, DISABLE, BIRTH_DEFECT, OTHER_MEDS, CUR_ILL, HISTORY, PRIOR_VAX from vaers_staging.Events
# Out:
#        VAERS_ID  ONSET_DATE RECOVD  DIED DATEDIED L_THREAT OFC_VISIT ER_VISIT  \
# 0        794224  2018-12-29   None  None     None     None      None     None
# 1        794226  2018-12-28   None  None     None     None      None     None
# 2        794359  2000-01-14      N  None     None     None      None     None
# 3        794763        None      U  None     None     None      None     None
# 4        795410  2019-01-05   None  None     None     None      None     None
# ...         ...         ...    ...   ...      ...      ...       ...      ...
# 44339    839583  2019-10-03      N  None     None     None      True     None
# 44340    798122  2019-01-18      Y  None     None     None      True     None
# 44341    843026        None      Y  None     None     None      None     None
# 44342    827038  2019-08-02      N  None     None     None      None     None
# 44343    805825        None      U  None     None     None      None     None
#
#       ER_ED_VISIT HOSPITAL  HOSPDAYS X_STAY DISABLE BIRTH_DEFECT  \
# 0            None     None       NaN   None    None         None
# 1            None     None       NaN   None    None         None
# 2            True     None       NaN   None    None         None
# 3            None     None       NaN   None    None         None
# 4            None     None       NaN   None    None         None
# ...           ...      ...       ...    ...     ...          ...
# 44339        None     None       NaN   None    None         None
# 44340        None     None       NaN   None    None         None
# 44341        None     None       NaN   None    None         None
# 44342        None     None       NaN   None    None         None
# 44343        None     None       NaN   None    None         None
#
#                                               OTHER_MEDS  \
# 0                                                   None
# 1      WELLBUTRIN; omeprazole; verapamil; fish oil; m...
# 2      Prescription: PLAQUENIL, FLORINEF, PRILOSEC, m...
# 3                        Just vitamin C; zinc, B complex
# 4               Lorsartan; amlodipine; multivitamin; B13
# ...                                                  ...
# 44339  Synthroid, Zoloft, ASA, Preservision AREDS 2, ...
# 44340                                               None
# 44341                                               None
# 44342                                               None
# 44343                                               None
#
#                                                  CUR_ILL  \
# 0                                                   None
# 1                                                   None
# 2                                             None known
# 3                   Productive persistent cough; fatigue
# 4                                                   None
# ...                                                  ...
# 44339  No illness at time of vaccination.  No illness...
# 44340                                               None
# 44341                                               None
# 44342                                               None
# 44343                                               None
#
#                                                  HISTORY PRIOR_VAX
# 0                                                   None      None
# 1      High BP; Elevated cholesterol; GERD; No alcoho...      None
# 2                                                  Lupus      None
# 3                                                  None.      None
# 4                                                    HTN      None
# ...                                                  ...       ...
# 44339  HTN heart disease w/o failure, unspecified psy...      None
# 44340                                               None      None
# 44341                                               None      None
# 44342                                               None      None
# 44343                                               None      None
#
# [44344 rows x 18 columns]

# %% [markdown]
# ### Generate Primary Key for Symptom table. No other changes made to table as Symptom is an entity by itself.

# %%
# %%bigquery
# create table vaers_modeled.Symptom as
# select DISTINCT ROW_NUMBER() OVER() as SYMPTOM_ID, VAERS_ID, SYMPTOM1, SYMPTOM2, SYMPTOM3, SYMPTOM4, SYMPTOM5
# from vaers_staging.Symptoms
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select * from vaers_modeled.Symptom
# limit 10
# Out:
#    SYMPTOM_ID  VAERS_ID SYMPTOM1  SYMPTOM2 SYMPTOM3 SYMPTOM4 SYMPTOM5
# 0        8649    836654      Tic      None     None     None     None
# 1        5418    820782      Tic      None     None     None     None
# 2        3608    811540      Tic      None     None     None     None
# 3       13391    821476      Tic    Tremor     None     None     None
# 4       12214    809042     Acne      Rash     None     None     None
# 5       16245    827723     Acne  Pruritus     None     None     None
# 6       11414    808547     Acne      Pain     None     None     None
# 7         220    795240     Acne      None     None     None     None
# 8       10585    846795     Coma      None     None     None     None
# 9       15197    800927     Coma   Seizure     None     None     None

# %% [markdown]
# ### Creating table joining patient information from Events table with Symptoms table. Entity is patient.

# %%
# %%bigquery
# create table vaers_modeled.Patient_Event as
# select e.VAERS_ID, e.STATE, e.AGE_YRS, e.SEX, e.DIED, e.DATEDIED, e.L_THREAT, e.ER_VISIT, e.HOSPITAL, e.HOSPDAYS, e.X_STAY, e.DISABLE,
# e.RECOVD, e.OTHER_MEDS, e.CUR_ILL, e.BIRTH_DEFECT, e.ALLERGIES,
# s.SYMPTOM1, s.SYMPTOM2, s.SYMPTOM3, s.SYMPTOM4, s.SYMPTOM5
# from vaers_staging.Events e, vaers_staging.Symptoms s
# where e.VAERS_ID = s.VAERS_ID
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select * from vaers_modeled.Patient_Event
# where state is not null and died is not null
# limit 10
# #Added where clause to show more information
# Out:
#    VAERS_ID STATE  AGE_YRS SEX  DIED    DATEDIED L_THREAT ER_VISIT HOSPITAL  \
# 0    834405    AR     1.00   M  True  2018-09-22     None     None     None
# 1    806371    AR     0.92   F  True  2019-03-02     None     None     None
# 2    806371    AR     0.92   F  True  2019-03-02     None     None     None
# 3    844189    AR    75.00   M  True  2019-10-29     None     None     None
# 4    844189    AR    75.00   M  True  2019-10-29     None     None     None
# 5    815652    AZ     0.50   F  True  2019-05-22     None     None     None
# 6    809231    CA     0.17   M  True  2015-01-30     None     None     None
# 7    823271    CA     0.08   F  True  2019-07-02     None     None     None
# 8    826060    CA      NaN   F  True        None     None     None     None
# 9    840255    CA    55.00   F  True  2019-10-05     None     None     None
#
#   HOSPDAYS  ... RECOVD                                         OTHER_MEDS  \
# 0     None  ...      N                                              None.
# 1     None  ...      N                                  Tylenol for pain.
# 2     None  ...      N                                  Tylenol for pain.
# 3     None  ...      N  Levemir, Pravastatin, Furosemide, Lisinopril, ...
# 4     None  ...      N  Levemir, Pravastatin, Furosemide, Lisinopril, ...
# 5     None  ...      N                                               None
# 6     None  ...      N                                               None
# 7     None  ...      N                                               None
# 8     None  ...      N                                               None
# 9     None  ...      N                                               none
#
#                                              CUR_ILL BIRTH_DEFECT  \
# 0                                              None.         None
# 1                                               None         None
# 2                                               None         None
# 3                                     Diabetes, COPD         None
# 4                                     Diabetes, COPD         None
# 5  Mild congestion earlier in month.  Ongoing tee...         None
# 6                                         Runny nose         None
# 7                                               None         None
# 8                                               None         None
# 9                                               none         None
#
#             ALLERGIES            SYMPTOM1                 SYMPTOM2  \
# 0               None.  Decreased appetite                  Pyrexia
# 1               Latex          Blood test                    Death
# 2               Latex      Urine analysis                     None
# 3                none          Aspiration                 Cyanosis
# 4                none             Syncope  Unresponsive to stimuli
# 5  No known allergies               Death            Resuscitation
# 6                None         Hypersomnia      Poor feeding infant
# 7                None               Death       Decreased appetite
# 8                None               Death                     None
# 9                  no                Pain             Palpitations
#
#                    SYMPTOM3            SYMPTOM4       SYMPTOM5
# 0                      None                None           None
# 1  Eyelid function disorder  Febrile convulsion        Pyrexia
# 2                      None                None           None
# 3                     Death        Pulse absent  Resuscitation
# 4                      None                None           None
# 5   Unresponsive to stimuli                None           None
# 6                      None                None           None
# 7                      None                None           None
# 8                      None                None           None
# 9                      None                None           None
#
# [10 rows x 22 columns]

# %% [markdown]
# ### Showing Report table has PK

# %%
# %%bigquery
# select count(*) as count from vaers_modeled.Report
# Out:
#    count
# 0  44344

# %%
# %%bigquery
# select count(distinct VAERS_ID) as count from vaers_modeled.Report
# Out:
#    count
# 0  44344

# %% [markdown]
# ### Showing duplicates of VAERS_ID in Patient_Event and Vaccine_Event tables
# ##### As there are less distinct VAERS_ID values than the total number of rows, there exists duplicates of VAERS_ID
# ##### Also, given that the count of distinct VAERS_ID matches the count of PK above, we know that referential integrity is preserved

# %%
# %%bigquery
# select count(*) as count from vaers_modeled.Vaccine_Event
# Out:
#    count
# 0  56272

# %%
# %%bigquery
# select count(distinct VAERS_ID) as count from vaers_modeled.Vaccine_Event
# Out:
#    count
# 0  44344

# %%
# %%bigquery
# select count(*) as count from vaers_modeled.Patient_Event
# Out:
#    count
# 0  55260

# %%
# %%bigquery
# select count(distinct VAERS_ID) as count from vaers_modeled.Patient_Event
# Out:
#    count
# 0  44343

# %% [markdown]
# ### Queries showing the duplicate entries. Explanations in TRANSFORMS.txt

# %%
# %%bigquery
# select v1.* from vaers_modeled.Vaccine_Event v1
# join (SELECT VAERS_ID, COUNT(*)
# FROM vaers_modeled.Vaccine_Event
# group by VAERS_ID
# HAVING count(*) > 1) v2
# on v1.VAERS_ID = v2.VAERS_ID
# order by v1.VAERS_ID
# limit 10
# Out:
#    VAERS_ID    VAX_DATE  ONSET_DATE V_ADMINBY V_FUNDBY PRIOR_VAX VAX_TYPE  \
# 0    794159  2018-12-27  2018-12-28       PVT     None      None     MMRV
# 1    794159  2018-12-27  2018-12-28       PVT     None      None  DTAPIPV
# 2    794162  2018-12-19  2018-12-26       PVT     None      None     HEPA
# 3    794162  2018-12-19  2018-12-26       PVT     None      None     MMRV
# 4    794165  2018-12-28  2018-12-28       PHM     None      None    PNC13
# 5    794165  2018-12-28  2018-12-28       PHM     None      None     FLU3
# 6    794170  2018-12-20  2018-12-30       PVT     None      None   VARCEL
# 7    794170  2018-12-20  2018-12-30       PVT     None      None     HEPA
# 8    794170  2018-12-20  2018-12-30       PVT     None      None      MMR
# 9    794178  2018-11-14  2018-11-29       MIL     None      None    SMALL
#
#                                           VAX_NAME  \
# 0  MEASLES + MUMPS + RUBELLA + VARICELLA (PROQUAD)
# 1                              DTAP + IPV (KINRIX)
# 2                                   HEP A (HAVRIX)
# 3  MEASLES + MUMPS + RUBELLA + VARICELLA (PROQUAD)
# 4                               PNEUMO (PREVNAR13)
# 5         INFLUENZA (SEASONAL) (FLUZONE HIGH-DOSE)
# 6                              VARICELLA (VARIVAX)
# 7                                    HEP A (VAQTA)
# 8               MEASLES + MUMPS + RUBELLA (MMR II)
# 9                              SMALLPOX (ACAM2000)
#
#                       VAX_MANU VAX_ROUTE VAX_SITE
# 0             MERCK & CO. INC.        SC       LL
# 1  GLAXOSMITHKLINE BIOLOGICALS        IM       LL
# 2  GLAXOSMITHKLINE BIOLOGICALS        IM       LL
# 3             MERCK & CO. INC.        IM       RL
# 4                 PFIZER\WYETH        IM       RA
# 5               SANOFI PASTEUR        IM       LA
# 6             MERCK & CO. INC.        IM       LL
# 7             MERCK & CO. INC.        IM       RL
# 8             MERCK & CO. INC.        IM       LL
# 9               SANOFI PASTEUR      None       LA

# %%
# %%bigquery
# select p1.* from vaers_modeled.Patient_Event p1
# join (SELECT VAERS_ID, COUNT(*)
# FROM vaers_modeled.Patient_Event
# group by VAERS_ID
# HAVING count(*) > 1) p2
# on p1.VAERS_ID = p2.VAERS_ID
# order by p1.VAERS_ID
# limit 10
# Out:
#    VAERS_ID STATE  AGE_YRS SEX  DIED DATEDIED L_THREAT ER_VISIT HOSPITAL  \
# 0    794157    IL     68.0   F  None     None     None     None     None
# 1    794157    IL     68.0   F  None     None     None     None     None
# 2    794160    TX     79.0   F  None     None     None     None     None
# 3    794160    TX     79.0   F  None     None     None     None     None
# 4    794163    MA     65.0   F  None     None     None     None     None
# 5    794163    MA     65.0   F  None     None     None     None     None
# 6    794168    MA     43.0   M  None     None     None     None     None
# 7    794168    MA     43.0   M  None     None     None     None     None
# 8    794168    MA     43.0   M  None     None     None     None     None
# 9    794175  None     66.0   F  None     None     None     None     None
#
#   HOSPDAYS  ... DISABLE                                         OTHER_MEDS  \
# 0     None  ...    None  Levothyroxine, sertraline, vitamin B complex, ...
# 1     None  ...    None  Levothyroxine, sertraline, vitamin B complex, ...
# 2     None  ...    None  ATORVASTATIN; CELEBREX; XYZAL; D-3; ELIQUIS; A...
# 3     None  ...    None  ATORVASTATIN; CELEBREX; XYZAL; D-3; ELIQUIS; A...
# 4     None  ...    None  Extra strength arthritis Tylenol, Simvastatin,...
# 5     None  ...    None  Extra strength arthritis Tylenol, Simvastatin,...
# 6     None  ...    None                              probiotics; magnesium
# 7     None  ...    None                              probiotics; magnesium
# 8     None  ...    None                              probiotics; magnesium
# 9     None  ...    None                                               none
#
#                                              CUR_ILL BIRTH_DEFECT  \
# 0                                               None         None
# 1                                               None         None
# 2  SINUSITIS; ATHROSCLEROSIS; DIABETES; HYPERCHOL...         None
# 3  SINUSITIS; ATHROSCLEROSIS; DIABETES; HYPERCHOL...         None
# 4                                               None         None
# 5                                               None         None
# 6                                               None         None
# 7                                               None         None
# 8                                               None         None
# 9                                               none         None
#
#                   ALLERGIES                                   SYMPTOM1  \
# 0                      None                                     Apathy
# 1                      None                    Injection site pruritus
# 2            ACE INHIBITORS                                   Asthenia
# 3            ACE INHIBITORS                    Injection site swelling
# 4  Chocolate, nuts, legumes                                    Myalgia
# 5  Chocolate, nuts, legumes                             Abdominal pain
# 6                      NKDA                                   Vomiting
# 7                      NKDA                                  Dizziness
# 8                      NKDA  Nuclear magnetic resonance imaging normal
# 9                      none           Injected limb mobility decreased
#
#                   SYMPTOM2               SYMPTOM3                 SYMPTOM4  \
# 0               Arthralgia               Asthenia  Injection site erythema
# 1  Injection site swelling  Injection site warmth                 Listless
# 2                   Chills                Fatigue   Influenza like illness
# 3              Lip blister           Lip swelling                     Pain
# 4                   Nausea                Pyrexia                     None
# 5               Arthralgia              Dizziness                  Fatigue
# 6                     None                   None                     None
# 7                 Ear pain          Labyrinthitis                 Migraine
# 8                 Tinnitus                Vertigo      Vestibular migraine
# 9      Injection site pain  Loss of consciousness                     None
#
#                   SYMPTOM5
# 0      Injection site pain
# 1             Night sweats
# 2  Injection site erythema
# 3                     None
# 4                     None
# 5                 Headache
# 6                     None
# 7                   Nausea
# 8          Viral infection
# 9                     None
#
# [10 rows x 21 columns]
