# %% [markdown]
# ### Ingest data from VAERS dataset

# %%
dataset_id = "vaers_staging"
# !bq --location=US mk --dataset {dataset_id}
# Out:
# BigQuery error in mk operation: Dataset 'studied-brand-266702:vaers_staging'
# already exists.

# %%
# !bq --location=US load --autodetect --skip_leading_rows=1 --ignore_unknown_values \
--source_format=CSV {dataset_id}.Events 'gs://cs327e_project_data/vaccine_data/2019VAERSDATA.csv'
# Out:
# Waiting on bqjob_r6deb892c4c021968_0000017041a986fa_1 ... (10s) Current status: DONE

# %%
# !bq --location=US load --autodetect --skip_leading_rows=1 --ignore_unknown_values \
--source_format=CSV {dataset_id}.Symptoms 'gs://cs327e_project_data/vaccine_data/2019VAERSSYMPTOMS.csv'
# Out:
# Waiting on bqjob_r33fd917c2d7713c4_0000017041a9b727_1 ... (2s) Current status: DONE

# %%
# !bq --location=US load --autodetect --skip_leading_rows=1 \
--source_format=CSV {dataset_id}.Vaccines 'gs://cs327e_project_data/vaccine_data/2019VAERSVAX.csv'
# Out:
# Waiting on bqjob_r42d6a3180606ab4_0000017041a9c8a3_1 ... (2s) Current status: DONE

# %% [markdown]
# ### View sample records from each dataset

# %%
# Remove limit on number of columns shown
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
# %%bigquery
# select * from vaers_staging.Events
# limit 5
# # View sample records of events table
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS CAGE_YR CAGE_MO SEX RPT_DATE  \
# 0    794224  2019-01-02  None     51.0    None    None   F     None
# 1    794226  2019-01-02  None     65.0    None    None   F     None
# 2    794359  2019-01-02    OH     18.0    None    None   U     None
# 3    794763  2019-01-06    NC     28.0    None    None   F     None
# 4    795410  2019-01-09  None      NaN    None    None   F     None
#
#                                         SYMPTOM_TEXT  DIED DATEDIED L_THREAT  \
# 0  Receive second dose of SHINGRIX on 12/28/18. N...  None     None     None
# 1  Received SHINGRIX vaccine (first dose) and the...  None     None     None
# 2  Patient had swelling and redness, but also had...  None     None     None
# 3  Fatigue, pain, development of itchy sores on r...  None     None     None
# 4  Vaccine administered on 5th 24 hours later red...  None     None     None
#
#   ER_VISIT HOSPITAL HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  ONSET_DATE  \
# 0     None     None     None   None    None   None  2018-12-28  2018-12-29
# 1     None     None     None   None    None   None  2018-12-27  2018-12-28
# 2     None     None     None   None    None      N        None  2000-01-14
# 3     None     None     None   None    None      U        None        None
# 4     None     None     None   None    None   None  2019-01-05  2019-01-05
#
#    NUMDAYS                                           LAB_DATA V_ADMINBY  \
# 0      1.0                                               None       UNK
# 1      1.0                                               None       UNK
# 2      NaN                No tests were done, patient called.       PHM
# 3      NaN  Symptoms have gradually presented, have not do...       PHM
# 4      0.0                                               None       UNK
#
#   V_FUNDBY                                         OTHER_MEDS  \
# 0     None                                               None
# 1     None  WELLBUTRIN; omeprazole; verapamil; fish oil; m...
# 2     None  Prescription: PLAQUENIL, FLORINEF, PRILOSEC, m...
# 3     None                    Just vitamin C; zinc, B complex
# 4     None           Lorsartan; amlodipine; multivitamin; B13
#
#                                 CUR_ILL  \
# 0                                  None
# 1                                  None
# 2                            None known
# 3  Productive persistent cough; fatigue
# 4                                  None
#
#                                              HISTORY PRIOR_VAX SPLTTYPE  \
# 0                                               None      None     None
# 1  High BP; Elevated cholesterol; GERD; No alcoho...      None     None
# 2                                              Lupus      None     None
# 3                                              None.      None     None
# 4                                                HTN      None     None
#
#    FORM_VERS TODAYS_DATE BIRTH_DEFECT OFC_VISIT ER_ED_VISIT  \
# 0          2  2018-12-30         None      None        None
# 1          2  2018-12-29         None      None        None
# 2          2  2019-01-02         None      None        True
# 3          2  2019-01-06         None      None        None
# 4          2  2019-01-08         None      None        None
#
#                                      ALLERGIES
# 0                                      aspirin
# 1                                      Statins
# 2                                 Methotrexate
# 3  Latex, reaction to unknown chemical in lab.
# 4                                      Heparin

# %%
# %%bigquery
# select * from vaers_staging.Symptoms where symptom2 is not NULL
# limit 5
# # View sample records of symptoms table
# Out:
#    VAERS_ID            SYMPTOM1  SYMPTOMVERSION1 SYMPTOM2  SYMPTOMVERSION2  \
# 0    794252                Rash             22.0      Tic             22.0
# 1    795935             Fatigue             22.0      Tic             22.0
# 2    818880     Throat clearing             22.0      Tic             22.0
# 3    824337  Abnormal behaviour             22.0      Tic             22.0
# 4    825003    Muscle twitching             22.0      Tic             22.0
#
#     SYMPTOM3  SYMPTOMVERSION3 SYMPTOM4 SYMPTOMVERSION4 SYMPTOM5  \
# 0  Urticaria             22.0     None            None     None
# 1       None              NaN     None            None     None
# 2       None              NaN     None            None     None
# 3       None              NaN     None            None     None
# 4       None              NaN     None            None     None
#
#   SYMPTOMVERSION5
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None

# %%
# %%bigquery
# select * from vaers_staging.Vaccines
# limit 5
# # View sample records of vaccines table
# Out:
#    VAERS_ID VAX_TYPE        VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE  \
# 0    801118     HIBV  SANOFI PASTEUR     None             UNK      None
# 1    801239     HIBV  SANOFI PASTEUR     None             UNK      None
# 2    803164     HIBV  SANOFI PASTEUR  UI917AA             UNK        UN
# 3    804902     HIBV  SANOFI PASTEUR     None             UNK      None
# 4    807785     HIBV  SANOFI PASTEUR     None               1      None
#
#   VAX_SITE      VAX_NAME
# 0     None  HIB (ACTHIB)
# 1     None  HIB (ACTHIB)
# 2     None  HIB (ACTHIB)
# 3     None  HIB (ACTHIB)
# 4     None  HIB (ACTHIB)

# %% [markdown]
# ### Explore data using queries

# %%
# %%bigquery
# select * from vaers_staging.Events where died=TRUE and hospital=TRUE and age_yrs is not null order by age_yrs
# limit 10
# # This query looks at patients went to the hospital after their adverse event and died. 10 youngest individuals shown first.
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0    800352  2019-02-06    WA     0.17      0.0      0.2   M     None
# 1    800352  2019-02-06    WA     0.17      0.0      0.2   M     None
# 2    847509  2019-11-14  None     0.17      NaN      NaN   M     None
# 3    847509  2019-11-14  None     0.17      NaN      NaN   M     None
# 4    823707  2019-07-16    KY     0.33      0.0      0.3   F     None
# 5    801369  2019-02-13    NC     0.33      0.0      0.3   M     None
# 6    823707  2019-07-16    KY     0.33      0.0      0.3   F     None
# 7    801369  2019-02-13    NC     0.33      0.0      0.3   M     None
# 8    851409  2019-12-06    NJ     0.42      0.0      0.5   M     None
# 9    851409  2019-12-06    NJ     0.42      0.0      0.5   M     None
#
#                                         SYMPTOM_TEXT  DIED    DATEDIED  \
# 0  Over the next 4 days, showed a lack of smiling...  True  2019-01-31
# 1  Over the next 4 days, showed a lack of smiling...  True  2019-01-31
# 2  metabolic acidosis; failure to thrive; develop...  True  2007-08-25
# 3  metabolic acidosis; failure to thrive; develop...  True  2007-08-25
# 4  Pt's mother states that pt had fever for 24hrs...  True  2019-07-12
# 5  Child was in office on February 12th for his f...  True  2019-02-13
# 6  Pt's mother states that pt had fever for 24hrs...  True  2019-07-12
# 7  Child was in office on February 12th for his f...  True  2019-02-13
# 8  Dear Officer, My five months old son passed aw...  True  2019-10-28
# 9  Dear Officer, My five months old son passed aw...  True  2019-10-28
#
#   L_THREAT ER_VISIT  HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  \
# 0     None     None      True       6.0   None    None      N  2019-01-24
# 1     None     None      True       6.0   None    None      N  2019-01-24
# 2     None     None      True       NaN   None    None      N  2007-08-23
# 3     None     None      True       NaN   None    None      N  2007-08-23
# 4     None     None      True       NaN   None    None   None  2019-06-26
# 5     None     None      True       NaN   None    None      N  2019-02-12
# 6     None     None      True       NaN   None    None   None  2019-06-26
# 7     None     None      True       NaN   None    None      N  2019-02-12
# 8     None     None      True       5.0   None    None      N  2019-10-23
# 9     None     None      True       5.0   None    None      N  2019-10-23
#
#    ONSET_DATE  NUMDAYS                                           LAB_DATA  \
# 0  2019-01-30        6  2/4/2019 (6th hospital day on ventilator, 5 da...
# 1  2019-01-30        6  2/4/2019 (6th hospital day on ventilator, 5 da...
# 2  2007-08-25        2                                               None
# 3  2007-08-25        2                                               None
# 4  2019-07-11       15                                               None
# 5  2019-02-12        0                                               None
# 6  2019-07-11       15                                               None
# 7  2019-02-12        0                                               None
# 8  2019-10-23        0                                               None
# 9  2019-10-23        0                                               None
#
#   V_ADMINBY V_FUNDBY                                         OTHER_MEDS  \
# 0       PVT     None                                               None
# 1       PVT     None                                               None
# 2       UNK     None                                               None
# 3       UNK     None                                               None
# 4       UNK     None                                               None
# 5       PVT     None  mupirocin topical ointment; desonide topical c...
# 6       UNK     None                                               None
# 7       PVT     None  mupirocin topical ointment; desonide topical c...
# 8       OTH     None                                    Vitamin D drops
# 9       OTH     None                                    Vitamin D drops
#
#                                              CUR_ILL  HISTORY PRIOR_VAX  \
# 0                                               None     None      None
# 1                                               None     None      None
# 2                   Congenital anomaly; Immunization     None      None
# 3                   Congenital anomaly; Immunization     None      None
# 4                                               None     None      None
# 5                                   Nasal congestion     None      None
# 6                                               None     None      None
# 7                                   Nasal congestion     None      None
# 8  1. mild fever - fever about 100 centigrade ( o...  Nothing      None
# 9  1. mild fever - fever about 100 centigrade ( o...  Nothing      None
#
#                    SPLTTYPE  FORM_VERS TODAYS_DATE BIRTH_DEFECT OFC_VISIT  \
# 0                      None          2  2019-02-06         None      None
# 1                      None          2  2019-02-06         None      None
# 2  US0095075131911USA003240          2  2019-11-14         None      None
# 3  US0095075131911USA003240          2  2019-11-14         None      None
# 4                      None          2  2019-07-16         None      None
# 5                      None          2  2019-02-13         None      None
# 6                      None          2  2019-07-16         None      None
# 7                      None          2  2019-02-13         None      None
# 8                      None          2  2019-12-06         None      None
# 9                      None          2  2019-12-06         None      None
#
#   ER_ED_VISIT ALLERGIES
# 0        None      None
# 1        None      None
# 2        None      None
# 3        None      None
# 4        None      None
# 5        None      NKDA
# 6        None      None
# 7        None      NKDA
# 8        True   Nothing
# 9        True   Nothing

# %%
# %%bigquery
# select * from vaers_staging.Events where age_yrs<10 and er_visit=TRUE order by sex
# limit 20
# # This query looks at the children under 10 that visited the ER after their adverse event with females appearing first followed by males.
# Out:
#     VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX    RPT_DATE  \
# 0     803247  2019-02-26    LA     0.33      0.0      0.4   F  2019-02-25
# 1     805254  2019-03-13    PA     0.08      0.0      0.1   F  2019-03-12
# 2     795462  2019-01-09    CA     1.25      1.0      0.3   F  2019-01-09
# 3     844111  2019-10-29    VA     0.20      0.0      0.2   F  2019-10-25
# 4     807662  2019-03-28    LA     0.17      0.0      0.2   F  2019-03-28
# 5     811059  2019-04-22    FL     1.00      1.0      0.1   F  2019-04-22
# 6     803460  2019-02-27    GA     0.17      0.0      0.2   F  2019-02-18
# 7     818388  2019-06-11    LA     0.33      0.0      0.4   F  2019-06-11
# 8     832076  2019-09-05    MS     0.83      0.0      0.9   F  2019-09-04
# 9     821708  2019-07-03    NY     0.50      0.0      0.4   F  2019-06-25
# 10    819090  2019-06-14    MI     1.00      1.0      0.1   F  2019-06-06
# 11    801181  2019-02-11    VA     1.33      1.0      0.4   F  2019-02-11
# 12    832927  2019-09-10    CO     0.08      0.0      0.2   F  2019-09-10
# 13    823437  2019-07-12    NJ     0.17      0.0      0.2   F  2019-07-12
# 14    815644  2019-05-23    TN     5.00      NaN      NaN   F  2019-05-23
# 15    818255  2019-06-10    NJ     1.00      1.0      0.0   F  2019-06-04
# 16    811360  2019-04-25    NY     1.00      1.0      0.0   F  2019-04-25
# 17    807902  2019-03-29    IN     0.33      0.0      0.3   F  2019-03-26
# 18    806031  2019-03-18    NY     0.50      0.0      0.5   F  2018-08-02
# 19    796935  2019-01-22    KY     0.50      0.0      0.6   F  2019-01-21
#
#                                          SYMPTOM_TEXT  DIED DATEDIED L_THREAT  \
# 0   Fussy, restless, no sleep after vaccines. Afte...  None     None     True
# 1   Patient was seen on 3/8/19 at medical practice...  None     None     None
# 2   A few hours after PENTACEL (DTAP/IPV/HIB) and ...  None     None     None
# 3   2mo with seizure like activity after vaccinati...  None     None     None
# 4   Patient was presented to ER with fever of 102 ...  None     None     None
# 5   Mom states when driving home, child was white ...  None     None     None
# 6   Rash developing 2 days after vaccines. Startin...  None     None     None
# 7   RV given 5/17/19. Pt did well till 5/25/19. Pt...  None     None     True
# 8   Mom said child began having tremors + spasms l...  None     None     None
# 9   Fever + fussiness started the day after vaccin...  None     None     None
# 10  At 12 mo WCC concerns raised about intermitten...  None     None     None
# 11  17 mo who developed fever, LAOM and acute tinn...  None     None     None
# 12  9/10/19 - 65 day old female with blood in stoo...  None     None     None
# 13  Intussusception, Ileocolic: Dx 7/1/19 -vomitin...  None     None     None
# 14  Red, warm to touch, larger area(5in wx2.5in) a...  None     None     None
# 15  9:28AM Developed local urticaria at varicella ...  None     None     None
# 16  Fussiness, nasal congestion, rhinorrhea starte...  None     None     None
# 17  Four episodes of "tremors" or spams that laste...  None     None     None
# 18  7-31-18 -Started with a blotchy rash from head...  None     None     None
# 19  Immunizations on 11/8/18. Mother noticed knot ...  None     None     None
#
#     ER_VISIT HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  ONSET_DATE  \
# 0       True     True       NaN   None    None      N  2019-02-19        None
# 1       True     None       NaN   None    None      Y  2019-03-08  2019-03-08
# 2       True     None       NaN   None    None      Y  2019-01-07  2019-01-07
# 3       True     None       NaN   None    None      Y  2019-10-03  2019-10-03
# 4       True     None       NaN   None    None      Y  2019-03-26  2019-03-27
# 5       True     None       NaN   None    None      Y  2019-04-22  2019-04-22
# 6       True     None       NaN   None    None      Y  2019-02-11  2019-02-13
# 7       True     True       4.0   None    None      Y  2019-05-17  2019-05-25
# 8       True     None       NaN   None    None      Y  2019-09-03  2019-09-03
# 9       True     None       NaN   None    None      U  2019-06-21  2019-06-22
# 10      True     None       NaN   None    None   None  2019-04-16  2019-05-05
# 11      True     None       NaN   None    None      Y  2019-01-29  2019-02-07
# 12      True     None       NaN   None    None      U  2019-09-06  2019-09-09
# 13      True     True       NaN   None    None      Y  2019-06-14  2019-07-01
# 14      True     None       NaN   None    None   None        None        None
# 15      True     None       NaN   None    None      Y  2019-05-23  2019-05-23
# 16      True     None       NaN   None    None      U  2019-04-15  2019-04-24
# 17      True     None       NaN   None    None   None  2019-03-25  2019-03-25
# 18      True     None       NaN   None    None      Y  2018-07-30  2018-07-31
# 19      True     True       1.0   None    None      U  2018-11-08  2018-12-12
#
#     NUMDAYS                                           LAB_DATA V_ADMINBY  \
# 0       NaN  MRI Brain Spine, normal; EEG, Neg; CBC, BMP, P...       PVT
# 1       0.0                                               None       PVT
# 2       0.0                                               None       PVT
# 3       0.0                                           EEG - NL       PVT
# 4       1.0                                CBC; XRAY; Flu; RSV       PVT
# 5       0.0                                               None       PVT
# 6       2.0                                               None       PVT
# 7       8.0          Ultrasound - positive for intussusception       PVT
# 8       0.0                                         EEG ordred       PUB
# 9       1.0                                               none       PVT
# 10     19.0                                               None       PVT
# 11      9.0  CBC-WNL; Bld Cx-Negative; T Cx-Negative; U Cx-...       PVT
# 12      3.0    hemoccult of stool - positive for blood 9/10/19       PVT
# 13     17.0  XR Abdomen, US Abdomen, CMP, CBC POCT Glucose,...       PVT
# 14      NaN                            Cellulitis to (L) thigh       PVT
# 15      0.0                                               None       PVT
# 16      9.0                                               none       PVT
# 17      0.0                                                 No       PVT
# 18      1.0  CBC-7/31/19; WBC 8.6, bands 1; Hgb 13.3; Throa...       PVT
# 19     34.0  Abscess culture done 1/17/19; Final culture-no...       PVT
#
#    V_FUNDBY                                     OTHER_MEDS  \
# 0       UNK                                           None
# 1       PUB                                           None
# 2       PVT                                           None
# 3       PVT                                              O
# 4       PUB                                           None
# 5       PUB                                           None
# 6       PUB                                           None
# 7       PVT                                           None
# 8       PUB                                           None
# 9       PVT                                           None
# 10      PVT  Now on trilepta but 0 meds at time of vaccine
# 11      PUB                                           None
# 12      PVT                                             NA
# 13      PVT                                           None
# 14      PUB                                           None
# 15      PVT                                           None
# 16      PUB                                           None
# 17      PVT                                             No
# 18      PUB                                           None
# 19      PUB                                           None
#
#                     CUR_ILL  \
# 0                      None
# 1                      None
# 2     Cold, cough x 10 days
# 3                      None
# 4                      None
# 5                       N/A
# 6                        No
# 7                      none
# 8                      None
# 9                      none
# 10                     none
# 11                     None
# 12                       NA
# 13                     None
# 14                     None
# 15                     None
# 16               congestion
# 17  Gastroesophageal reflux
# 18                     none
# 19                     None
#
#                                               HISTORY PRIOR_VAX SPLTTYPE  \
# 0                                                None      None     None
# 1                                                None      None     None
# 2                                                None      None     None
# 3                                                None      None     None
# 4                                                None      None     None
# 5                                                 N/A      None     None
# 6                                                None      None     None
# 7                                                none      None     None
# 8                                                None      None     None
# 9                                                  no      None     None
# 10                             Beta thalassemia trait      None     None
# 11                                               None      None     None
# 12  Laryngotracheitis, Thrush, Torticollis, Positi...      None     None
# 13                                               None      None     None
# 14                                               None      None     None
# 15                  Milk protein allergy - resolved -      None     None
# 16                                          exotropia      None     None
# 17                              seborrheic dermatitis      None     None
# 18                                               none      None     None
# 19                                               None      None     None
#
#     FORM_VERS TODAYS_DATE BIRTH_DEFECT OFC_VISIT ER_ED_VISIT ALLERGIES
# 0           1        None         None      None        None      None
# 1           1        None         None      None        None      None
# 2           1        None         None      None        None      None
# 3           1        None         None      None        None      None
# 4           1        None         None      None        None      None
# 5           1        None         None      None        None      None
# 6           1        None         None      None        None      None
# 7           1        None         None      None        None      None
# 8           1        None         None      None        None      None
# 9           1        None         None      None        None      None
# 10          1        None         None      None        None      None
# 11          1        None         None      None        None      None
# 12          1        None         None      None        None      None
# 13          1        None         None      None        None      None
# 14          1        None         None      None        None      None
# 15          1        None         None      None        None      None
# 16          1        None         None      None        None      None
# 17          1        None         None      None        None      None
# 18          1        None         None      None        None      None
# 19          1        None         None      None        None      None

# %%
# %%bigquery
# select * from vaers_staging.Symptoms where symptom1='Nausea' and symptom2='Vomiting'
# limit 5
# # This query looks at patients that had nausea and vomiting listed as their first two symptoms. Order by not used because nothing to order by
# # with just this table alone.
# Out:
#    VAERS_ID SYMPTOM1  SYMPTOMVERSION1  SYMPTOM2  SYMPTOMVERSION2 SYMPTOM3  \
# 0    803601   Nausea             22.0  Vomiting             22.0     None
# 1    804638   Nausea             22.0  Vomiting             22.0     None
# 2    805134   Nausea             22.0  Vomiting             22.0     None
# 3    807269   Nausea             22.0  Vomiting             22.0     None
# 4    811401   Nausea             22.0  Vomiting             22.0     None
#
#   SYMPTOMVERSION3 SYMPTOM4 SYMPTOMVERSION4 SYMPTOM5 SYMPTOMVERSION5
# 0            None     None            None     None            None
# 1            None     None            None     None            None
# 2            None     None            None     None            None
# 3            None     None            None     None            None
# 4            None     None            None     None            None

# %%
# %%bigquery
# select * from vaers_staging.Vaccines where vax_type='FLUX' and vax_manu!='UNKNOWN MANUFACTURER'
# # This query looks at the FLUX flu vaccines that have a listed manufacturer. This is interesting because most of the FLUX vaccines are listed
# # without a known manufacturer. Once again order by not used because nothing to order by.
# Out:
#    VAERS_ID VAX_TYPE        VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE  \
# 0    842071     FLUX  SANOFI PASTEUR    59TS2             UNK        IM
# 1    802105     FLUX  SANOFI PASTEUR  UI980AA               5        UN
# 2    796905     FLUX  SANOFI PASTEUR     None             UNK        UN
# 3    842071     FLUX  SANOFI PASTEUR    59TS2             UNK        IM
# 4    802105     FLUX  SANOFI PASTEUR  UI980AA               5        UN
# 5    796905     FLUX  SANOFI PASTEUR     None             UNK        UN
#
#   VAX_SITE                              VAX_NAME
# 0       LA  INFLUENZA (SEASONAL) (NO BRAND NAME)
# 1       RA  INFLUENZA (SEASONAL) (NO BRAND NAME)
# 2       UN  INFLUENZA (SEASONAL) (NO BRAND NAME)
# 3       LA  INFLUENZA (SEASONAL) (NO BRAND NAME)
# 4       RA  INFLUENZA (SEASONAL) (NO BRAND NAME)
# 5       UN  INFLUENZA (SEASONAL) (NO BRAND NAME)
